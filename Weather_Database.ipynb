# %%
#Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate a new set of 1,500 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lats_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 629

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        #Rain data
        try:
            city_rain = city_weather["rain"]["3h"]
            
        except:
            city_rain = 0.00 
            
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0.00
            
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                            "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,                                                         
                             "Current Description":city_weather_description,
                              "Rain inches (last 3hrs)":city_rain,
                                "Snow inches (last 3hrs)":city_snow})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaqortoq
# Processing Record 2 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | samana
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | ushtobe
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | rawson
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | cherskiy
# Processing Record 16 of Set 1 | warrnambool
# Processing Record 17 of Set 1 | ilulissat
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | muroto
# Processing Record 21 of Set 1 | tanabe
# Processing Record 22 of Set 1 | ponta do sol
# Processing Record 23 of Set 1 | provideniya
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | debelec
# Processing Record 27 of Set 1 | narsaq
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | brasilia
# Processing Record 33 of Set 1 | lasa
# Processing Record 34 of Set 1 | zhanaozen
# Processing Record 35 of Set 1 | kucevo
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | shakhtinsk
# Processing Record 38 of Set 1 | matara
# Processing Record 39 of Set 1 | zachagansk
# City not found. Skipping...
# Processing Record 40 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 1 | nanortalik
# Processing Record 42 of Set 1 | argos orestikon
# City not found. Skipping...
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | brae
# Processing Record 45 of Set 1 | sungurlu
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | gizo
# Processing Record 48 of Set 1 | pachino
# Processing Record 49 of Set 1 | san andres
# Processing Record 50 of Set 1 | sinnamary
# Processing Record 1 of Set 2 | surt
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | svirstroy
# Processing Record 4 of Set 2 | san patricio
# Processing Record 5 of Set 2 | chokwe
# Processing Record 6 of Set 2 | sampit
# Processing Record 7 of Set 2 | edd
# Processing Record 8 of Set 2 | esperance
# Processing Record 9 of Set 2 | malacacheta
# Processing Record 10 of Set 2 | andenes
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | fortuna
# Processing Record 14 of Set 2 | paita
# Processing Record 15 of Set 2 | goundi
# Processing Record 16 of Set 2 | yertsevo
# Processing Record 17 of Set 2 | obo
# Processing Record 18 of Set 2 | loa janan
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | marystown
# Processing Record 21 of Set 2 | sept-iles
# Processing Record 22 of Set 2 | kolokani
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 2 | lugovoy
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | butaritari
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | bac can
# City not found. Skipping...
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | vardo
# Processing Record 32 of Set 2 | rikitea
# Processing Record 33 of Set 2 | waingapu
# Processing Record 34 of Set 2 | miquelon
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | gorkovskoye
# City not found. Skipping...
# Processing Record 38 of Set 2 | san ignacio
# Processing Record 39 of Set 2 | horta
# Processing Record 40 of Set 2 | totma
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | muros
# Processing Record 43 of Set 2 | namatanai
# Processing Record 44 of Set 2 | iqaluit
# Processing Record 45 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2 | cap malheureux
# Processing Record 47 of Set 2 | shelopugino
# Processing Record 48 of Set 2 | piet retief
# Processing Record 49 of Set 2 | portland
# Processing Record 50 of Set 2 | east london
# Processing Record 1 of Set 3 | castro
# Processing Record 2 of Set 3 | lavrentiya
# Processing Record 3 of Set 3 | sibolga
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | kununurra
# Processing Record 6 of Set 3 | parga
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | matay
# Processing Record 9 of Set 3 | atuona
# Processing Record 10 of Set 3 | rio grande
# Processing Record 11 of Set 3 | schattdorf
# Processing Record 12 of Set 3 | hithadhoo
# Processing Record 13 of Set 3 | salalah
# Processing Record 14 of Set 3 | pithora
# Processing Record 15 of Set 3 | albany
# Processing Record 16 of Set 3 | dahanu
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | xining
# Processing Record 19 of Set 3 | ventspils
# Processing Record 20 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 3 | souillac
# Processing Record 22 of Set 3 | akita
# Processing Record 23 of Set 3 | pochutla
# Processing Record 24 of Set 3 | sao filipe
# Processing Record 25 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 3 | luderitz
# Processing Record 27 of Set 3 | vostok
# Processing Record 28 of Set 3 | camacha
# Processing Record 29 of Set 3 | roald
# Processing Record 30 of Set 3 | goderich
# Processing Record 31 of Set 3 | tautira
# Processing Record 32 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 3 | ostrovnoy
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | roma
# Processing Record 36 of Set 3 | chuy
# Processing Record 37 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 3 | ola
# Processing Record 39 of Set 3 | putnok
# Processing Record 40 of Set 3 | zhigansk
# Processing Record 41 of Set 3 | nacala
# Processing Record 42 of Set 3 | tumut
# Processing Record 43 of Set 3 | biltine
# Processing Record 44 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 3 | puerto escondido
# Processing Record 46 of Set 3 | marawi
# Processing Record 47 of Set 3 | tripoli
# Processing Record 48 of Set 3 | jibuti
# Processing Record 49 of Set 3 | boshnyakovo
# Processing Record 50 of Set 3 | hibbing
# Processing Record 1 of Set 4 | maniwaki
# Processing Record 2 of Set 4 | stornoway
# Processing Record 3 of Set 4 | parfenyevo
# Processing Record 4 of Set 4 | bethel
# Processing Record 5 of Set 4 | carnarvon
# Processing Record 6 of Set 4 | hovd
# Processing Record 7 of Set 4 | coquimbo
# Processing Record 8 of Set 4 | chokurdakh
# Processing Record 9 of Set 4 | sonoita
# Processing Record 10 of Set 4 | seoul
# Processing Record 11 of Set 4 | shimanovsk
# Processing Record 12 of Set 4 | black river
# Processing Record 13 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 4 | menongue
# Processing Record 15 of Set 4 | havelock
# Processing Record 16 of Set 4 | sotouboua
# Processing Record 17 of Set 4 | leningradskiy
# Processing Record 18 of Set 4 | kudat
# Processing Record 19 of Set 4 | yarovoye
# Processing Record 20 of Set 4 | biak
# Processing Record 21 of Set 4 | cayenne
# Processing Record 22 of Set 4 | necochea
# Processing Record 23 of Set 4 | sangar
# Processing Record 24 of Set 4 | ponta delgada
# Processing Record 25 of Set 4 | nabire
# Processing Record 26 of Set 4 | port elizabeth
# Processing Record 27 of Set 4 | grindavik
# Processing Record 28 of Set 4 | oussouye
# Processing Record 29 of Set 4 | corinto
# Processing Record 30 of Set 4 | sahrak
# City not found. Skipping...
# Processing Record 31 of Set 4 | ashland
# Processing Record 32 of Set 4 | agadez
# Processing Record 33 of Set 4 | buala
# Processing Record 34 of Set 4 | orikum
# Processing Record 35 of Set 4 | abu samrah
# Processing Record 36 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 4 | waipawa
# Processing Record 38 of Set 4 | vestmannaeyjar
# Processing Record 39 of Set 4 | karratha
# Processing Record 40 of Set 4 | whitehorse
# Processing Record 41 of Set 4 | torbay
# Processing Record 42 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 4 | tongchuan
# Processing Record 44 of Set 4 | kropotkin
# Processing Record 45 of Set 4 | kamaishi
# Processing Record 46 of Set 4 | zarand
# Processing Record 47 of Set 4 | vila do maio
# Processing Record 48 of Set 4 | khalkhal
# Processing Record 49 of Set 4 | chicama
# Processing Record 50 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 5 | norman wells
# Processing Record 2 of Set 5 | saint-augustin
# Processing Record 3 of Set 5 | port hardy
# Processing Record 4 of Set 5 | kahului
# Processing Record 5 of Set 5 | labuhan
# Processing Record 6 of Set 5 | dubbo
# Processing Record 7 of Set 5 | sobolevo
# Processing Record 8 of Set 5 | thompson
# Processing Record 9 of Set 5 | meadow lake
# Processing Record 10 of Set 5 | sorland
# Processing Record 11 of Set 5 | hambantota
# Processing Record 12 of Set 5 | san jeronimo
# Processing Record 13 of Set 5 | bongaree
# Processing Record 14 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 5 | rundu
# Processing Record 16 of Set 5 | ixtapa
# Processing Record 17 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 5 | okhotsk
# Processing Record 19 of Set 5 | huarmey
# Processing Record 20 of Set 5 | teruel
# Processing Record 21 of Set 5 | nemuro
# Processing Record 22 of Set 5 | gamba
# Processing Record 23 of Set 5 | kruisfontein
# Processing Record 24 of Set 5 | walvis bay
# Processing Record 25 of Set 5 | taoudenni
# Processing Record 26 of Set 5 | sola
# Processing Record 27 of Set 5 | kodiak
# Processing Record 28 of Set 5 | neyshabur
# Processing Record 29 of Set 5 | aklavik
# Processing Record 30 of Set 5 | george town
# Processing Record 31 of Set 5 | fukuma
# Processing Record 32 of Set 5 | rio verde de mato grosso
# Processing Record 33 of Set 5 | airai
# Processing Record 34 of Set 5 | grootfontein
# Processing Record 35 of Set 5 | mahebourg
# Processing Record 36 of Set 5 | magway
# Processing Record 37 of Set 5 | mohnesee
# Processing Record 38 of Set 5 | jingdezhen
# Processing Record 39 of Set 5 | abbeville
# Processing Record 40 of Set 5 | bathsheba
# Processing Record 41 of Set 5 | ndola
# Processing Record 42 of Set 5 | jining
# Processing Record 43 of Set 5 | lorengau
# Processing Record 44 of Set 5 | srednekolymsk
# Processing Record 45 of Set 5 | alexandria
# Processing Record 46 of Set 5 | dunda
# Processing Record 47 of Set 5 | papar
# Processing Record 48 of Set 5 | stettler
# Processing Record 49 of Set 5 | tiznit
# Processing Record 50 of Set 5 | eureka
# Processing Record 1 of Set 6 | osakarovka
# Processing Record 2 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 6 | meiningen
# Processing Record 5 of Set 6 | nizhniy kuranakh
# Processing Record 6 of Set 6 | longyearbyen
# Processing Record 7 of Set 6 | praia
# Processing Record 8 of Set 6 | sao joao da barra
# Processing Record 9 of Set 6 | upernavik
# Processing Record 10 of Set 6 | salme
# Processing Record 11 of Set 6 | christchurch
# Processing Record 12 of Set 6 | vyazemskiy
# Processing Record 13 of Set 6 | okato
# Processing Record 14 of Set 6 | saint george
# Processing Record 15 of Set 6 | progreso
# Processing Record 16 of Set 6 | khatanga
# Processing Record 17 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 6 | yambio
# Processing Record 19 of Set 6 | moose factory
# Processing Record 20 of Set 6 | lompoc
# Processing Record 21 of Set 6 | coos bay
# Processing Record 22 of Set 6 | pangoa
# Processing Record 23 of Set 6 | ghanzi
# Processing Record 24 of Set 6 | nome
# Processing Record 25 of Set 6 | khandyga
# Processing Record 26 of Set 6 | jatai
# Processing Record 27 of Set 6 | dunmore east
# Processing Record 28 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 6 | katsuura
# Processing Record 30 of Set 6 | rio gallegos
# Processing Record 31 of Set 6 | acapulco
# Processing Record 32 of Set 6 | dongli
# Processing Record 33 of Set 6 | sainte-marie
# Processing Record 34 of Set 6 | fairbanks
# Processing Record 35 of Set 6 | arman
# Processing Record 36 of Set 6 | faanui
# Processing Record 37 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 38 of Set 6 | tanete
# Processing Record 39 of Set 6 | hofn
# Processing Record 40 of Set 6 | helena
# Processing Record 41 of Set 6 | kaoma
# Processing Record 42 of Set 6 | el faiyum
# City not found. Skipping...
# Processing Record 43 of Set 6 | xapuri
# Processing Record 44 of Set 6 | hamilton
# Processing Record 45 of Set 6 | gladstone
# Processing Record 46 of Set 6 | caninde de sao francisco
# Processing Record 47 of Set 6 | huilong
# Processing Record 48 of Set 6 | miri
# Processing Record 49 of Set 6 | moyale
# Processing Record 50 of Set 6 | abu kamal
# Processing Record 1 of Set 7 | egvekinot
# Processing Record 2 of Set 7 | inuvik
# Processing Record 3 of Set 7 | kieta
# Processing Record 4 of Set 7 | alghero
# Processing Record 5 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 7 | merauke
# Processing Record 7 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 7 | kavaratti
# Processing Record 9 of Set 7 | auburn
# Processing Record 10 of Set 7 | sosva
# Processing Record 11 of Set 7 | sitka
# Processing Record 12 of Set 7 | dingle
# Processing Record 13 of Set 7 | khartoum
# Processing Record 14 of Set 7 | vanimo
# Processing Record 15 of Set 7 | tura
# Processing Record 16 of Set 7 | zaraza
# Processing Record 17 of Set 7 | turayf
# Processing Record 18 of Set 7 | nouadhibou
# Processing Record 19 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 7 | angoche
# Processing Record 21 of Set 7 | muzquiz
# City not found. Skipping...
# Processing Record 22 of Set 7 | jacareacanga
# Processing Record 23 of Set 7 | kalabo
# Processing Record 24 of Set 7 | tommot
# Processing Record 25 of Set 7 | darhan
# Processing Record 26 of Set 7 | husavik
# Processing Record 27 of Set 7 | lisakovsk
# Processing Record 28 of Set 7 | cabo san lucas
# Processing Record 29 of Set 7 | tuatapere
# Processing Record 30 of Set 7 | yarada
# Processing Record 31 of Set 7 | hami
# Processing Record 32 of Set 7 | plettenberg bay
# Processing Record 33 of Set 7 | sao joao do piaui
# Processing Record 34 of Set 7 | shaoxing
# Processing Record 35 of Set 7 | zeya
# Processing Record 36 of Set 7 | shingu
# Processing Record 37 of Set 7 | haines junction
# Processing Record 38 of Set 7 | hasaki
# Processing Record 39 of Set 7 | mahanoro
# Processing Record 40 of Set 7 | paamiut
# Processing Record 41 of Set 7 | saint-joseph
# Processing Record 42 of Set 7 | hay river
# Processing Record 43 of Set 7 | freeport
# Processing Record 44 of Set 7 | santa cruz
# Processing Record 45 of Set 7 | schwabach
# Processing Record 46 of Set 7 | zhicheng
# Processing Record 47 of Set 7 | cleveland
# Processing Record 48 of Set 7 | yanahuanca
# Processing Record 49 of Set 7 | sakhon nakhon
# Processing Record 50 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 1 of Set 8 | broken hill
# Processing Record 2 of Set 8 | shaunavon
# Processing Record 3 of Set 8 | almeirim
# Processing Record 4 of Set 8 | saint-paul-les-dax
# Processing Record 5 of Set 8 | letlhakane
# Processing Record 6 of Set 8 | west wendover
# Processing Record 7 of Set 8 | buhe
# Processing Record 8 of Set 8 | kimbe
# Processing Record 9 of Set 8 | cherusti
# Processing Record 10 of Set 8 | atbasar
# Processing Record 11 of Set 8 | pimentel
# Processing Record 12 of Set 8 | evansville
# Processing Record 13 of Set 8 | ucluelet
# Processing Record 14 of Set 8 | kudahuvadhoo
# Processing Record 15 of Set 8 | lieksa
# Processing Record 16 of Set 8 | aviles
# Processing Record 17 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 8 | deputatskiy
# Processing Record 19 of Set 8 | cidreira
# Processing Record 20 of Set 8 | ismailia
# Processing Record 21 of Set 8 | kaitangata
# Processing Record 22 of Set 8 | clyde river
# Processing Record 23 of Set 8 | inhambane
# Processing Record 24 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 8 | mount gambier
# Processing Record 26 of Set 8 | middle island
# Processing Record 27 of Set 8 | sayaxche
# Processing Record 28 of Set 8 | tabuk
# Processing Record 29 of Set 8 | metsavan
# Processing Record 30 of Set 8 | biu
# Processing Record 31 of Set 8 | mujiayingzi
# Processing Record 32 of Set 8 | chuguyevka
# Processing Record 33 of Set 8 | smolenskoye
# Processing Record 34 of Set 8 | atka
# City not found. Skipping...
# Processing Record 35 of Set 8 | piacabucu
# Processing Record 36 of Set 8 | rock sound
# Processing Record 37 of Set 8 | antigonish
# Processing Record 38 of Set 8 | los llanos de aridane
# Processing Record 39 of Set 8 | nurota
# Processing Record 40 of Set 8 | batagay-alyta
# Processing Record 41 of Set 8 | bilibino
# Processing Record 42 of Set 8 | asau
# Processing Record 43 of Set 8 | cairns
# Processing Record 44 of Set 8 | umm bab
# Processing Record 45 of Set 8 | bridgetown
# Processing Record 46 of Set 8 | timizart
# Processing Record 47 of Set 8 | vao
# Processing Record 48 of Set 8 | amapa
# Processing Record 49 of Set 8 | palma del rio
# Processing Record 50 of Set 8 | zyryanka
# Processing Record 1 of Set 9 | portachuelo
# Processing Record 2 of Set 9 | sao jose da coroa grande
# Processing Record 3 of Set 9 | tiksi
# Processing Record 4 of Set 9 | medina
# Processing Record 5 of Set 9 | acari
# Processing Record 6 of Set 9 | mount isa
# Processing Record 7 of Set 9 | beringovskiy
# Processing Record 8 of Set 9 | schopfheim
# Processing Record 9 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 9 | flinders
# Processing Record 11 of Set 9 | ormara
# Processing Record 12 of Set 9 | puerto cabezas
# Processing Record 13 of Set 9 | constitucion
# Processing Record 14 of Set 9 | nantucket
# Processing Record 15 of Set 9 | saldanha
# Processing Record 16 of Set 9 | laguna
# Processing Record 17 of Set 9 | puksoozero
# Processing Record 18 of Set 9 | turukhansk
# Processing Record 19 of Set 9 | half moon bay
# Processing Record 20 of Set 9 | uglegorskiy
# Processing Record 21 of Set 9 | kutum
# Processing Record 22 of Set 9 | weston
# Processing Record 23 of Set 9 | contai
# Processing Record 24 of Set 9 | la rioja
# Processing Record 25 of Set 9 | baracoa
# Processing Record 26 of Set 9 | pacifica
# Processing Record 27 of Set 9 | blonduos
# City not found. Skipping...
# Processing Record 28 of Set 9 | ancud
# Processing Record 29 of Set 9 | bajo baudo
# City not found. Skipping...
# Processing Record 30 of Set 9 | paredon
# Processing Record 31 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 32 of Set 9 | vrangel
# Processing Record 33 of Set 9 | mehamn
# Processing Record 34 of Set 9 | san cristobal
# Processing Record 35 of Set 9 | tanout
# Processing Record 36 of Set 9 | broome
# Processing Record 37 of Set 9 | lukow
# Processing Record 38 of Set 9 | padang
# Processing Record 39 of Set 9 | ndioum
# Processing Record 40 of Set 9 | qingdao
# Processing Record 41 of Set 9 | iskateley
# Processing Record 42 of Set 9 | basoko
# Processing Record 43 of Set 9 | benicarlo
# Processing Record 44 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 9 | bitung
# Processing Record 46 of Set 9 | dudinka
# Processing Record 47 of Set 9 | gbarnga
# Processing Record 48 of Set 9 | porto novo
# Processing Record 49 of Set 9 | the valley
# Processing Record 50 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 1 of Set 10 | gigmoto
# Processing Record 2 of Set 10 | imbituba
# Processing Record 3 of Set 10 | alta floresta
# Processing Record 4 of Set 10 | fukue
# Processing Record 5 of Set 10 | kupang
# Processing Record 6 of Set 10 | pangody
# Processing Record 7 of Set 10 | galesong
# Processing Record 8 of Set 10 | maceio
# Processing Record 9 of Set 10 | rawlins
# Processing Record 10 of Set 10 | japura
# Processing Record 11 of Set 10 | santa cruz de tenerife
# Processing Record 12 of Set 10 | acarau
# Processing Record 13 of Set 10 | seymchan
# Processing Record 14 of Set 10 | buncrana
# Processing Record 15 of Set 10 | zaysan
# Processing Record 16 of Set 10 | keetmanshoop
# Processing Record 17 of Set 10 | tomatlan
# Processing Record 18 of Set 10 | marsaxlokk
# Processing Record 19 of Set 10 | talnakh
# Processing Record 20 of Set 10 | aswan
# Processing Record 21 of Set 10 | batticaloa
# Processing Record 22 of Set 10 | hualmay
# Processing Record 23 of Set 10 | termiz
# Processing Record 24 of Set 10 | pisco
# Processing Record 25 of Set 10 | belyy yar
# Processing Record 26 of Set 10 | malkangiri
# Processing Record 27 of Set 10 | teya
# Processing Record 28 of Set 10 | maniitsoq
# Processing Record 29 of Set 10 | yulara
# Processing Record 30 of Set 10 | acajutiba
# Processing Record 31 of Set 10 | sahuaripa
# Processing Record 32 of Set 10 | ozernovskiy
# Processing Record 33 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 34 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 10 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 36 of Set 10 | nakusp
# Processing Record 37 of Set 10 | bull savanna
# Processing Record 38 of Set 10 | ambon
# Processing Record 39 of Set 10 | bukene
# Processing Record 40 of Set 10 | ust-omchug
# Processing Record 41 of Set 10 | careiro da varzea
# Processing Record 42 of Set 10 | shimoda
# Processing Record 43 of Set 10 | urusha
# Processing Record 44 of Set 10 | kysyl-syr
# Processing Record 45 of Set 10 | puri
# Processing Record 46 of Set 10 | juneau
# Processing Record 47 of Set 10 | wuda
# Processing Record 48 of Set 10 | pali
# Processing Record 49 of Set 10 | alanya
# Processing Record 50 of Set 10 | urumqi
# Processing Record 1 of Set 11 | ambatofinandrahana
# Processing Record 2 of Set 11 | bambous virieux
# Processing Record 3 of Set 11 | santa cruz de la palma
# Processing Record 4 of Set 11 | bandrele
# Processing Record 5 of Set 11 | richards bay
# Processing Record 6 of Set 11 | elko
# Processing Record 7 of Set 11 | phrai bung
# City not found. Skipping...
# Processing Record 8 of Set 11 | ushirombo
# Processing Record 9 of Set 11 | vila velha
# Processing Record 10 of Set 11 | henties bay
# Processing Record 11 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 11 | ulladulla
# Processing Record 13 of Set 11 | codrington
# Processing Record 14 of Set 11 | sioux lookout
# Processing Record 15 of Set 11 | nagua
# Processing Record 16 of Set 11 | yelan
# Processing Record 17 of Set 11 | pergamino
# Processing Record 18 of Set 11 | yashkul
# Processing Record 19 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 11 | quesnel
# Processing Record 21 of Set 11 | bac lieu
# Processing Record 22 of Set 11 | magdagachi
# Processing Record 23 of Set 11 | deniliquin
# Processing Record 24 of Set 11 | kashi
# Processing Record 25 of Set 11 | tucuman
# Processing Record 26 of Set 11 | faya
# Processing Record 27 of Set 11 | vanavara
# Processing Record 28 of Set 11 | hirara
# Processing Record 29 of Set 11 | san jose
# Processing Record 30 of Set 11 | svetlyy
# Processing Record 31 of Set 11 | alofi
# Processing Record 32 of Set 11 | pangkalanbuun
# Processing Record 33 of Set 11 | komsomolskiy
# Processing Record 34 of Set 11 | phra phutthabat
# Processing Record 35 of Set 11 | northam
# Processing Record 36 of Set 11 | sarangani
# Processing Record 37 of Set 11 | sao felix do xingu
# Processing Record 38 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 11 | totness
# Processing Record 40 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 41 of Set 11 | isangel
# Processing Record 42 of Set 11 | bengkulu
# Processing Record 43 of Set 11 | sambava
# Processing Record 44 of Set 11 | lagoa
# Processing Record 45 of Set 11 | rathdrum
# Processing Record 46 of Set 11 | karasburg
# Processing Record 47 of Set 11 | bone
# Processing Record 48 of Set 11 | jales
# Processing Record 49 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 11 | naze
# Processing Record 1 of Set 12 | novyy urgal
# Processing Record 2 of Set 12 | libenge
# Processing Record 3 of Set 12 | dunedin
# Processing Record 4 of Set 12 | grinnell
# Processing Record 5 of Set 12 | bonfim
# Processing Record 6 of Set 12 | manta
# Processing Record 7 of Set 12 | mombetsu
# Processing Record 8 of Set 12 | cotonou
# Processing Record 9 of Set 12 | uvat
# Processing Record 10 of Set 12 | itarema
# Processing Record 11 of Set 12 | hope
# Processing Record 12 of Set 12 | ahipara
# Processing Record 13 of Set 12 | ochakiv
# Processing Record 14 of Set 12 | pevek
# Processing Record 15 of Set 12 | ternate
# Processing Record 16 of Set 12 | arlit
# Processing Record 17 of Set 12 | rockport
# Processing Record 18 of Set 12 | puerto leguizamo
# Processing Record 19 of Set 12 | colares
# Processing Record 20 of Set 12 | yamandu
# Processing Record 21 of Set 12 | yablonovo
# Processing Record 22 of Set 12 | batangafo
# Processing Record 23 of Set 12 | amga
# Processing Record 24 of Set 12 | moranbah
# Processing Record 25 of Set 12 | dwarka
# Processing Record 26 of Set 12 | klaksvik
# Processing Record 27 of Set 12 | touros
# Processing Record 28 of Set 12 | tela
# Processing Record 29 of Set 12 | campobello di mazara
# Processing Record 30 of Set 12 | tarko-sale
# Processing Record 31 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 32 of Set 12 | nioro
# Processing Record 33 of Set 12 | shelburne
# Processing Record 34 of Set 12 | guerrero negro
# Processing Record 35 of Set 12 | olinda
# Processing Record 36 of Set 12 | uyskoye
# Processing Record 37 of Set 12 | nyurba
# Processing Record 38 of Set 12 | fort nelson
# Processing Record 39 of Set 12 | praia da vitoria
# Processing Record 40 of Set 12 | tilichiki
# Processing Record 41 of Set 12 | namibe
# Processing Record 42 of Set 12 | bandar
# Processing Record 43 of Set 12 | charters towers
# Processing Record 44 of Set 12 | limbe
# Processing Record 45 of Set 12 | marsh harbour
# Processing Record 46 of Set 12 | skibbereen
# Processing Record 47 of Set 12 | bagotville
# Processing Record 48 of Set 12 | san policarpo
# Processing Record 49 of Set 12 | mitsamiouli
# Processing Record 50 of Set 12 | waitati
# Processing Record 1 of Set 13 | tahoua
# Processing Record 2 of Set 13 | chimore
# Processing Record 3 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 4 of Set 13 | jackson
# Processing Record 5 of Set 13 | kwinana
# Processing Record 6 of Set 13 | la palma
# Processing Record 7 of Set 13 | antalaha
# Processing Record 8 of Set 13 | port augusta
# Processing Record 9 of Set 13 | kovdor
# Processing Record 10 of Set 13 | tatarsk
# Processing Record 11 of Set 13 | anadyr
# Processing Record 12 of Set 13 | sorong
# Processing Record 13 of Set 13 | port blair
# Processing Record 14 of Set 13 | gotsu
# Processing Record 15 of Set 13 | college
# Processing Record 16 of Set 13 | general roca
# Processing Record 17 of Set 13 | szydlowiec
# Processing Record 18 of Set 13 | trelew
# Processing Record 19 of Set 13 | misratah
# Processing Record 20 of Set 13 | fukumitsu
# Processing Record 21 of Set 13 | quatre cocos
# Processing Record 22 of Set 13 | oktyabrskiy
# Processing Record 23 of Set 13 | kedrovyy
# Processing Record 24 of Set 13 | kamina
# Processing Record 25 of Set 13 | trairi
# Processing Record 26 of Set 13 | antsohihy
# Processing Record 27 of Set 13 | pelym
# Processing Record 28 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 29 of Set 13 | utiroa
# City not found. Skipping...
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
city_data
# Out:
# [{'City': 'Qaqortoq',
#   'Country': 'GL',
#   'Date': '2020-02-23 20:23:18',
#   'Lat': 60.72,
#   'Lng': -46.03,
#   'Max Temp': 24.8,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 9.17,
#   'Current Description': 'light snow',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.94},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Date': '2020-02-23 20:20:11',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 68,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 20.8,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Date': '2020-02-23 20:20:12',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 12.2,
#   'Humidity': 66,
#   'Cloudiness': 60,
#   'Wind Speed': 17.22,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Date': '2020-02-23 20:20:12',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': -4,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Samana',
#   'Country': 'DO',
#   'Date': '2020-02-23 20:20:12',
#   'Lat': 19.21,
#   'Lng': -69.34,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Date': '2020-02-23 20:20:12',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 61,
#   'Humidity': 81,
#   'Cloudiness': 50,
#   'Wind Speed': 2.01,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Date': '2020-02-23 20:20:13',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 55,
#   'Humidity': 89,
#   'Cloudiness': 77,
#   'Wind Speed': 5.01,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ushtobe',
#   'Country': 'KZ',
#   'Date': '2020-02-23 20:20:13',
#   'Lat': 45.25,
#   'Lng': 77.98,
#   'Max Temp': 30.9,
#   'Humidity': 87,
#   'Cloudiness': 93,
#   'Wind Speed': 1.92,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Date': '2020-02-23 20:20:13',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Date': '2020-02-23 20:20:13',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 55.4,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 32.21,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Date': '2020-02-23 20:20:13',
#   'Lat': -43.3,
#   'Lng': -65.1,
#   'Max Temp': 61.45,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 15.26,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Date': '2020-02-23 20:20:14',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 86,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 12.75,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:20:14',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -27.56,
#   'Humidity': 89,
#   'Cloudiness': 48,
#   'Wind Speed': 6.17,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Warrnambool',
#   'Country': 'AU',
#   'Date': '2020-02-23 20:20:14',
#   'Lat': -38.38,
#   'Lng': 142.48,
#   'Max Temp': 57.99,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.4,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Date': '2020-02-23 20:18:32',
#   'Lat': 69.22,
#   'Lng': -51.1,
#   'Max Temp': -4,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Date': '2020-02-23 20:16:36',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 51.8,
#   'Humidity': 24,
#   'Cloudiness': 1,
#   'Wind Speed': 19.46,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Date': '2020-02-23 20:18:24',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 54,
#   'Humidity': 90,
#   'Cloudiness': 66,
#   'Wind Speed': 4,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Muroto',
#   'Country': 'JP',
#   'Date': '2020-02-23 20:20:15',
#   'Lat': 33.28,
#   'Lng': 134.15,
#   'Max Temp': 39.16,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 4.94,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tanabe',
#   'Country': 'JP',
#   'Date': '2020-02-23 20:20:15',
#   'Lat': 33.73,
#   'Lng': 135.37,
#   'Max Temp': 35.01,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 6.89,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Date': '2020-02-23 20:20:15',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 68,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 19.46,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:20:16',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': -6.63,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 2.08,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Date': '2020-02-23 20:20:16',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': -19.41,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 7.14,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Date': '2020-02-23 20:20:01',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 57.2,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Debelec',
#   'Country': 'BG',
#   'Date': '2020-02-23 20:20:16',
#   'Lat': 43.03,
#   'Lng': 25.62,
#   'Max Temp': 45,
#   'Humidity': 93,
#   'Cloudiness': 91,
#   'Wind Speed': 3.36,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Date': '2020-02-23 20:20:16',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 24.8,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 9.17,
#   'Current Description': 'light snow',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 1.44},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Date': '2020-02-23 20:16:10',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Date': '2020-02-23 20:17:02',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 78.8,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Date': '2020-02-23 20:18:23',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 48.2,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 23.04,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Date': '2020-02-23 20:18:25',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 68,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Brasilia',
#   'Country': 'BR',
#   'Date': '2020-02-23 20:17:50',
#   'Lat': -15.78,
#   'Lng': -47.93,
#   'Max Temp': 80.6,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Lasa',
#   'Country': 'IT',
#   'Date': '2020-02-23 20:20:18',
#   'Lat': 46.62,
#   'Lng': 10.7,
#   'Max Temp': 50,
#   'Humidity': 91,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Zhanaozen',
#   'Country': 'KZ',
#   'Date': '2020-02-23 20:20:18',
#   'Lat': 43.3,
#   'Lng': 52.8,
#   'Max Temp': 43.48,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 7.29,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Kucevo',
#   'Country': 'RS',
#   'Date': '2020-02-23 20:20:18',
#   'Lat': 44.48,
#   'Lng': 21.67,
#   'Max Temp': 44.83,
#   'Humidity': 54,
#   'Cloudiness': 8,
#   'Wind Speed': 4.72,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Date': '2020-02-23 20:20:18',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': -5.8,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 18.34,
#   'Current Description': 'light snow',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Shakhtinsk',
#   'Country': 'KZ',
#   'Date': '2020-02-23 20:20:19',
#   'Lat': 49.71,
#   'Lng': 72.59,
#   'Max Temp': 17.6,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 6.71,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Matara',
#   'Country': 'LK',
#   'Date': '2020-02-23 20:17:18',
#   'Lat': 5.95,
#   'Lng': 80.54,
#   'Max Temp': 74.17,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 7.92,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Date': '2020-02-23 20:20:19',
#   'Lat': 60.14,
#   'Lng': -45.24,
#   'Max Temp': 27.72,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 1.72,
#   'Current Description': 'light snow',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.94},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Date': '2020-02-23 20:20:20',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 68,
#   'Humidity': 46,
#   'Cloudiness': 72,
#   'Wind Speed': 14.25,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Brae',
#   'Country': 'GB',
#   'Date': '2020-02-23 20:20:20',
#   'Lat': 60.4,
#   'Lng': -1.35,
#   'Max Temp': 35.6,
#   'Humidity': 81,
#   'Cloudiness': 96,
#   'Wind Speed': 19.46,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sungurlu',
#   'Country': 'TR',
#   'Date': '2020-02-23 20:20:20',
#   'Lat': 40.17,
#   'Lng': 34.37,
#   'Max Temp': 31.37,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 5.21,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Date': '2020-02-23 20:19:31',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 78.8,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Gizo',
#   'Country': 'SB',
#   'Date': '2020-02-23 20:20:21',
#   'Lat': -8.1,
#   'Lng': 156.84,
#   'Max Temp': 78.8,
#   'Humidity': 86,
#   'Cloudiness': 16,
#   'Wind Speed': 4.09,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Pachino',
#   'Country': 'IT',
#   'Date': '2020-02-23 20:20:21',
#   'Lat': 36.72,
#   'Lng': 15.09,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 67,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'San Andres',
#   'Country': 'CO',
#   'Date': '2020-02-23 20:20:21',
#   'Lat': 12.58,
#   'Lng': -81.7,
#   'Max Temp': 86,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sinnamary',
#   'Country': 'GF',
#   'Date': '2020-02-23 20:20:21',
#   'Lat': 5.38,
#   'Lng': -52.95,
#   'Max Temp': 78.96,
#   'Humidity': 81,
#   'Cloudiness': 87,
#   'Wind Speed': 15.17,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.13,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Surt',
#   'Country': 'LY',
#   'Date': '2020-02-23 20:23:31',
#   'Lat': 31.21,
#   'Lng': 16.59,
#   'Max Temp': 53.74,
#   'Humidity': 70,
#   'Cloudiness': 2,
#   'Wind Speed': 8.03,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Date': '2020-02-23 20:23:31',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 60.8,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Svirstroy',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:31',
#   'Lat': 60.8,
#   'Lng': 33.72,
#   'Max Temp': 33.73,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 8.34,
#   'Current Description': 'light snow',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.38},
#  {'City': 'San Patricio',
#   'Country': 'MX',
#   'Date': '2020-02-23 20:23:31',
#   'Lat': 19.22,
#   'Lng': -104.7,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 5,
#   'Wind Speed': 13.87,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Chokwe',
#   'Country': 'MZ',
#   'Date': '2020-02-23 20:23:32',
#   'Lat': -24.53,
#   'Lng': 32.98,
#   'Max Temp': 71.01,
#   'Humidity': 78,
#   'Cloudiness': 87,
#   'Wind Speed': 10.96,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sampit',
#   'Country': 'ID',
#   'Date': '2020-02-23 20:23:32',
#   'Lat': -2.53,
#   'Lng': 112.95,
#   'Max Temp': 75.33,
#   'Humidity': 95,
#   'Cloudiness': 13,
#   'Wind Speed': 1.97,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.5,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Edd',
#   'Country': 'ER',
#   'Date': '2020-02-23 20:23:32',
#   'Lat': 13.93,
#   'Lng': 41.69,
#   'Max Temp': 81.84,
#   'Humidity': 47,
#   'Cloudiness': 49,
#   'Wind Speed': 6.8,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Date': '2020-02-23 20:23:32',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 64.4,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Malacacheta',
#   'Country': 'BR',
#   'Date': '2020-02-23 20:23:33',
#   'Lat': -17.84,
#   'Lng': -42.08,
#   'Max Temp': 72.12,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.35,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3hrs)': 5.81,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Andenes',
#   'Country': 'NO',
#   'Date': '2020-02-23 20:23:33',
#   'Lat': 69.31,
#   'Lng': 16.12,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 35.57,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:18:34',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': 5.74,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 8.63,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:33',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 24.21,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 35.48,
#   'Current Description': 'snow',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 2.75},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Date': '2020-02-23 20:23:33',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 59,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 5.01,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Paita',
#   'Country': 'PE',
#   'Date': '2020-02-23 20:23:34',
#   'Lat': -5.09,
#   'Lng': -81.11,
#   'Max Temp': 62.6,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Goundi',
#   'Country': 'TD',
#   'Date': '2020-02-23 20:23:34',
#   'Lat': 9.36,
#   'Lng': 17.37,
#   'Max Temp': 84.2,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 7.74,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Yertsevo',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:34',
#   'Lat': 60.8,
#   'Lng': 40.09,
#   'Max Temp': 30.67,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 10.47,
#   'Current Description': 'light snow',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.81},
#  {'City': 'Obo',
#   'Country': 'CF',
#   'Date': '2020-02-23 20:23:34',
#   'Lat': 5.4,
#   'Lng': 26.49,
#   'Max Temp': 76.95,
#   'Humidity': 17,
#   'Cloudiness': 4,
#   'Wind Speed': 5.97,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Loa Janan',
#   'Country': 'ID',
#   'Date': '2020-02-23 20:23:34',
#   'Lat': -0.58,
#   'Lng': 117.09,
#   'Max Temp': 72.82,
#   'Humidity': 92,
#   'Cloudiness': 45,
#   'Wind Speed': 2.77,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Date': '2020-02-23 20:23:35',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 66.2,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Marystown',
#   'Country': 'CA',
#   'Date': '2020-02-23 20:23:35',
#   'Lat': 47.17,
#   'Lng': -55.15,
#   'Max Temp': 31.06,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 14.23,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sept-Iles',
#   'Country': 'CA',
#   'Date': '2020-02-23 20:20:47',
#   'Lat': 50.2,
#   'Lng': -66.38,
#   'Max Temp': 34,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Kolokani',
#   'Country': 'ML',
#   'Date': '2020-02-23 20:23:35',
#   'Lat': 13.57,
#   'Lng': -8.03,
#   'Max Temp': 85.44,
#   'Humidity': 10,
#   'Cloudiness': 37,
#   'Wind Speed': 8.37,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Date': '2020-02-23 20:21:12',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Lugovoy',
#   'Country': 'KZ',
#   'Date': '2020-02-23 20:23:36',
#   'Lat': 42.95,
#   'Lng': 72.76,
#   'Max Temp': 32.41,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.33,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Date': '2020-02-23 20:23:36',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 57,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Date': '2020-02-23 20:23:36',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 84.88,
#   'Humidity': 77,
#   'Cloudiness': 76,
#   'Wind Speed': 12.91,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3hrs)': 6,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Date': '2020-02-23 20:23:37',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Date': '2020-02-23 20:23:37',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Date': '2020-02-23 20:23:37',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 26.6,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'shower rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Date': '2020-02-23 20:23:37',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 79.2,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 6.13,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Waingapu',
#   'Country': 'ID',
#   'Date': '2020-02-23 20:18:46',
#   'Lat': -9.66,
#   'Lng': 120.26,
#   'Max Temp': 83.1,
#   'Humidity': 78,
#   'Cloudiness': 49,
#   'Wind Speed': 17.94,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Miquelon',
#   'Country': 'PM',
#   'Date': '2020-02-23 20:23:38',
#   'Lat': 47.1,
#   'Lng': -56.38,
#   'Max Temp': 33.8,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 14.99,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Date': '2020-02-23 20:23:38',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 63.63,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 9.86,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:38',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 37.4,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 11.18,
#   'Current Description': 'light intensity shower rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'San Ignacio',
#   'Country': 'BZ',
#   'Date': '2020-02-23 20:23:39',
#   'Lat': 17.16,
#   'Lng': -89.07,
#   'Max Temp': 84.2,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Horta',
#   'Country': 'PT',
#   'Date': '2020-02-23 20:23:39',
#   'Lat': 38.53,
#   'Lng': -28.63,
#   'Max Temp': 60.8,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Totma',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:39',
#   'Lat': 59.97,
#   'Lng': 42.76,
#   'Max Temp': 31.48,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 9.33,
#   'Current Description': 'light snow',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.56},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:39',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 28.47,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 27.6,
#   'Current Description': 'light snow',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.25},
#  {'City': 'Muros',
#   'Country': 'ES',
#   'Date': '2020-02-23 20:23:40',
#   'Lat': 42.78,
#   'Lng': -9.06,
#   'Max Temp': 60.01,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Namatanai',
#   'Country': 'PG',
#   'Date': '2020-02-23 20:23:40',
#   'Lat': -3.67,
#   'Lng': 152.43,
#   'Max Temp': 83.97,
#   'Humidity': 75,
#   'Cloudiness': 39,
#   'Wind Speed': 10.16,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Date': '2020-02-23 20:23:40',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': -23.01,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 13.87,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Cap Malheureux',
#   'Country': 'MU',
#   'Date': '2020-02-23 20:23:40',
#   'Lat': -19.98,
#   'Lng': 57.61,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Shelopugino',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:41',
#   'Lat': 51.65,
#   'Lng': 117.56,
#   'Max Temp': 1.15,
#   'Humidity': 95,
#   'Cloudiness': 0,
#   'Wind Speed': 2.26,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Piet Retief',
#   'Country': 'ZA',
#   'Date': '2020-02-23 20:23:41',
#   'Lat': -27.01,
#   'Lng': 30.81,
#   'Max Temp': 52.56,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 5.61,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.13,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Portland',
#   'Country': 'US',
#   'Date': '2020-02-23 20:20:21',
#   'Lat': 45.52,
#   'Lng': -122.68,
#   'Max Temp': 52,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 17.22,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Date': '2020-02-23 20:23:41',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 66.15,
#   'Humidity': 60,
#   'Cloudiness': 73,
#   'Wind Speed': 4.21,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Date': '2020-02-23 20:23:41',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 67.93,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 2.66,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:42',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': -7.56,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sibolga',
#   'Country': 'ID',
#   'Date': '2020-02-23 20:23:42',
#   'Lat': 1.74,
#   'Lng': 98.78,
#   'Max Temp': 70.74,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 4.03,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Kununurra',
#   'Country': 'AU',
#   'Date': '2020-02-23 20:23:42',
#   'Lat': -15.77,
#   'Lng': 128.73,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 78,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Parga',
#   'Country': 'GR',
#   'Date': '2020-02-23 20:23:43',
#   'Lat': 39.28,
#   'Lng': 20.4,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 46,
#   'Wind Speed': 1.99,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Date': '2020-02-23 20:19:46',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': -27.4,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 12.75,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Matay',
#   'Country': 'EG',
#   'Date': '2020-02-23 20:23:43',
#   'Lat': 28.42,
#   'Lng': 30.78,
#   'Max Temp': 48.34,
#   'Humidity': 67,
#   'Cloudiness': 51,
#   'Wind Speed': 4.68,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Date': '2020-02-23 20:23:43',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 81.61,
#   'Humidity': 76,
#   'Cloudiness': 8,
#   'Wind Speed': 13.73,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Rio Grande',
#   'Country': 'BR',
#   'Date': '2020-02-23 20:23:21',
#   'Lat': -32.03,
#   'Lng': -52.1,
#   'Max Temp': 77,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Schattdorf',
#   'Country': 'CH',
#   'Date': '2020-02-23 20:23:44',
#   'Lat': 46.87,
#   'Lng': 8.65,
#   'Max Temp': 64.4,
#   'Humidity': 36,
#   'Cloudiness': 20,
#   'Wind Speed': 13.87,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Date': '2020-02-23 20:23:44',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 83.41,
#   'Humidity': 76,
#   'Cloudiness': 92,
#   'Wind Speed': 13.69,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Date': '2020-02-23 20:23:44',
#   'Lat': 17.02,
#   'Lng': 54.09,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Pithora',
#   'Country': 'IN',
#   'Date': '2020-02-23 20:23:44',
#   'Lat': 21.27,
#   'Lng': 82.52,
#   'Max Temp': 67.73,
#   'Humidity': 71,
#   'Cloudiness': 29,
#   'Wind Speed': 5.53,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 1.25,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Date': '2020-02-23 20:23:44',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 52,
#   'Humidity': 29,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Dahanu',
#   'Country': 'IN',
#   'Date': '2020-02-23 20:23:45',
#   'Lat': 19.97,
#   'Lng': 72.73,
#   'Max Temp': 77.41,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 15.14,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Date': '2020-02-23 20:20:11',
#   'Lat': 22.29,
#   'Lng': 114.16,
#   'Max Temp': 68,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 14.99,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Xining',
#   'Country': 'CN',
#   'Date': '2020-02-23 20:23:45',
#   'Lat': 36.62,
#   'Lng': 101.77,
#   'Max Temp': 27.03,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 1.79,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ventspils',
#   'Country': 'LV',
#   'Date': '2020-02-23 20:23:45',
#   'Lat': 57.39,
#   'Lng': 21.56,
#   'Max Temp': 41,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Date': '2020-02-23 20:23:46',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Akita',
#   'Country': 'JP',
#   'Date': '2020-02-23 20:23:46',
#   'Lat': 39.72,
#   'Lng': 140.12,
#   'Max Temp': 43.12,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 25.03,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.25,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Pochutla',
#   'Country': 'MX',
#   'Date': '2020-02-23 20:23:46',
#   'Lat': 15.74,
#   'Lng': -96.47,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Date': '2020-02-23 20:23:46',
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Max Temp': 68.41,
#   'Humidity': 83,
#   'Cloudiness': 23,
#   'Wind Speed': 16.4,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Date': '2020-02-23 20:23:47',
#   'Lat': -26.65,
#   'Lng': 15.16,
#   'Max Temp': 71.46,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 24.92,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Vostok',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:47',
#   'Lat': 46.49,
#   'Lng': 135.88,
#   'Max Temp': 5.68,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.89,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Camacha',
#   'Country': 'PT',
#   'Date': '2020-02-23 20:23:47',
#   'Lat': 33.08,
#   'Lng': -16.33,
#   'Max Temp': 68,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 23.04,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Roald',
#   'Country': 'NO',
#   'Date': '2020-02-23 20:23:48',
#   'Lat': 62.58,
#   'Lng': 6.13,
#   'Max Temp': 37.4,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Goderich',
#   'Country': 'CA',
#   'Date': '2020-02-23 20:19:31',
#   'Lat': 43.75,
#   'Lng': -81.72,
#   'Max Temp': 46,
#   'Humidity': 59,
#   'Cloudiness': 17,
#   'Wind Speed': 4,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tautira',
#   'Country': 'PF',
#   'Date': '2020-02-23 20:23:48',
#   'Lat': -17.73,
#   'Lng': -149.15,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 14.99,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ostrovnoy',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:48',
#   'Lat': 68.05,
#   'Lng': 39.51,
#   'Max Temp': 29.05,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 15.93,
#   'Current Description': 'light snow',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.44},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Date': '2020-02-23 20:23:49',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Roma',
#   'Country': 'US',
#   'Date': '2020-02-23 20:22:40',
#   'Lat': 43.21,
#   'Lng': -75.46,
#   'Max Temp': 50,
#   'Humidity': 33,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Date': '2020-02-23 20:23:49',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 71.87,
#   'Humidity': 61,
#   'Cloudiness': 23,
#   'Wind Speed': 10.29,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ola',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:49',
#   'Lat': 59.58,
#   'Lng': 151.28,
#   'Max Temp': -8.52,
#   'Humidity': 91,
#   'Cloudiness': 47,
#   'Wind Speed': 6.35,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Putnok',
#   'Country': 'HU',
#   'Date': '2020-02-23 20:23:50',
#   'Lat': 48.3,
#   'Lng': 20.43,
#   'Max Temp': 47.14,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 19.46,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 2,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Zhigansk',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:50',
#   'Lat': 66.77,
#   'Lng': 123.37,
#   'Max Temp': -12.48,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 11.03,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Nacala',
#   'Country': 'MZ',
#   'Date': '2020-02-23 20:23:50',
#   'Lat': -14.54,
#   'Lng': 40.67,
#   'Max Temp': 76.6,
#   'Humidity': 97,
#   'Cloudiness': 54,
#   'Wind Speed': 4.41,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 1.38,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tumut',
#   'Country': 'AU',
#   'Date': '2020-02-23 20:23:50',
#   'Lat': -35.3,
#   'Lng': 148.22,
#   'Max Temp': 62.42,
#   'Humidity': 87,
#   'Cloudiness': 45,
#   'Wind Speed': 1.92,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Biltine',
#   'Country': 'TD',
#   'Date': '2020-02-23 20:23:50',
#   'Lat': 14.53,
#   'Lng': 20.92,
#   'Max Temp': 69.49,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 11.99,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Puerto Escondido',
#   'Country': 'MX',
#   'Date': '2020-02-23 20:23:51',
#   'Lat': 15.85,
#   'Lng': -97.07,
#   'Max Temp': 87.8,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Marawi',
#   'Country': 'PH',
#   'Date': '2020-02-23 20:23:51',
#   'Lat': 8,
#   'Lng': 124.29,
#   'Max Temp': 73.99,
#   'Humidity': 86,
#   'Cloudiness': 42,
#   'Wind Speed': 5.01,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tripoli',
#   'Country': 'LY',
#   'Date': '2020-02-23 20:21:23',
#   'Lat': 32.88,
#   'Lng': 13.19,
#   'Max Temp': 58.73,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 7.14,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Jibuti',
#   'Country': 'DJ',
#   'Date': '2020-02-23 20:23:51',
#   'Lat': 11.5,
#   'Lng': 42.5,
#   'Max Temp': 78.8,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 14.74,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Boshnyakovo',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:52',
#   'Lat': 49.63,
#   'Lng': 142.17,
#   'Max Temp': 12.22,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 11.16,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hibbing',
#   'Country': 'US',
#   'Date': '2020-02-23 20:23:52',
#   'Lat': 47.43,
#   'Lng': -92.94,
#   'Max Temp': 41,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 21.92,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Maniwaki',
#   'Country': 'CA',
#   'Date': '2020-02-23 20:23:52',
#   'Lat': 46.38,
#   'Lng': -75.97,
#   'Max Temp': 33.19,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.31,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Stornoway',
#   'Country': 'GB',
#   'Date': '2020-02-23 20:19:59',
#   'Lat': 58.21,
#   'Lng': -6.39,
#   'Max Temp': 36,
#   'Humidity': 80,
#   'Cloudiness': 15,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Parfenyevo',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:53',
#   'Lat': 58.48,
#   'Lng': 43.41,
#   'Max Temp': 32.4,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 11.16,
#   'Current Description': 'light snow',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.5},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Date': '2020-02-23 20:23:53',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 55.99,
#   'Humidity': 20,
#   'Cloudiness': 1,
#   'Wind Speed': 13.87,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Date': '2020-02-23 20:23:53',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hovd',
#   'Country': 'MN',
#   'Date': '2020-02-23 20:23:53',
#   'Lat': 48.01,
#   'Lng': 91.64,
#   'Max Temp': 15.84,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 0.92,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Date': '2020-02-23 20:18:55',
#   'Lat': -29.95,
#   'Lng': -71.34,
#   'Max Temp': 68,
#   'Humidity': 64,
#   'Cloudiness': 49,
#   'Wind Speed': 12.75,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:54',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': -20.96,
#   'Humidity': 97,
#   'Cloudiness': 77,
#   'Wind Speed': 2.82,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sonoita',
#   'Country': 'MX',
#   'Date': '2020-02-23 20:23:54',
#   'Lat': 31.85,
#   'Lng': -112.83,
#   'Max Temp': 63,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 12.48,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Seoul',
#   'Country': 'KR',
#   'Date': '2020-02-23 20:22:00',
#   'Lat': 37.57,
#   'Lng': 126.98,
#   'Max Temp': 33.8,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 1.12,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Shimanovsk',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:54',
#   'Lat': 52,
#   'Lng': 127.7,
#   'Max Temp': 6.67,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.07,
#   'Current Description': 'light snow',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.13},
#  {'City': 'Black River',
#   'Country': 'JM',
#   'Date': '2020-02-23 20:23:54',
#   'Lat': 18.03,
#   'Lng': -77.85,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 18.34,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Menongue',
#   'Country': 'AO',
#   'Date': '2020-02-23 20:23:55',
#   'Lat': -14.66,
#   'Lng': 17.69,
#   'Max Temp': 63.45,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3hrs)': 7,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Havelock',
#   'Country': 'US',
#   'Date': '2020-02-23 20:23:55',
#   'Lat': 34.88,
#   'Lng': -76.9,
#   'Max Temp': 64.4,
#   'Humidity': 23,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sotouboua',
#   'Country': 'TG',
#   'Date': '2020-02-23 20:23:55',
#   'Lat': 8.57,
#   'Lng': 0.98,
#   'Max Temp': 82.11,
#   'Humidity': 20,
#   'Cloudiness': 27,
#   'Wind Speed': 3.53,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:56',
#   'Lat': 69.38,
#   'Lng': 178.42,
#   'Max Temp': -14.89,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 5.88,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Kudat',
#   'Country': 'MY',
#   'Date': '2020-02-23 20:23:56',
#   'Lat': 6.88,
#   'Lng': 116.85,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Yarovoye',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:56',
#   'Lat': 52.93,
#   'Lng': 78.58,
#   'Max Temp': 14.02,
#   'Humidity': 96,
#   'Cloudiness': 67,
#   'Wind Speed': 3.13,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Biak',
#   'Country': 'ID',
#   'Date': '2020-02-23 20:23:56',
#   'Lat': -0.91,
#   'Lng': 122.88,
#   'Max Temp': 81.99,
#   'Humidity': 75,
#   'Cloudiness': 59,
#   'Wind Speed': 8.19,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Cayenne',
#   'Country': 'GF',
#   'Date': '2020-02-23 20:23:56',
#   'Lat': 4.93,
#   'Lng': -52.33,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Necochea',
#   'Country': 'AR',
#   'Date': '2020-02-23 20:23:57',
#   'Lat': -38.55,
#   'Lng': -58.74,
#   'Max Temp': 87.01,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 10,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sangar',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:23:57',
#   'Lat': 63.92,
#   'Lng': 127.47,
#   'Max Temp': -16.11,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.98,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ponta Delgada',
#   'Country': 'PT',
#   'Date': '2020-02-23 20:23:57',
#   'Lat': 37.73,
#   'Lng': -25.67,
#   'Max Temp': 59,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Nabire',
#   'Country': 'ID',
#   'Date': '2020-02-23 20:19:08',
#   'Lat': -3.37,
#   'Lng': 135.48,
#   'Max Temp': 72.88,
#   'Humidity': 99,
#   'Cloudiness': 97,
#   'Wind Speed': 0.89,
#   'Current Description': 'heavy intensity rain',
#   'Rain inches (last 3hrs)': 12.13,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Date': '2020-02-23 20:23:57',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 59,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Grindavik',
#   'Country': 'IS',
#   'Date': '2020-02-23 20:23:58',
#   'Lat': 63.84,
#   'Lng': -22.43,
#   'Max Temp': 33.8,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Oussouye',
#   'Country': 'SN',
#   'Date': '2020-02-23 20:23:58',
#   'Lat': 12.48,
#   'Lng': -16.55,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 88,
#   'Wind Speed': 6.93,
#   'Current Description': 'light rain',
# ...
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 4.25,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Amga',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:25:22',
#   'Lat': 60.9,
#   'Lng': 131.96,
#   'Max Temp': -12.75,
#   'Humidity': 99,
#   'Cloudiness': 90,
#   'Wind Speed': 1.66,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Moranbah',
#   'Country': 'AU',
#   'Date': '2020-02-23 20:25:22',
#   'Lat': -22,
#   'Lng': 148.05,
#   'Max Temp': 72,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 18.5,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Dwarka',
#   'Country': 'IN',
#   'Date': '2020-02-23 20:25:23',
#   'Lat': 22.24,
#   'Lng': 68.97,
#   'Max Temp': 76.08,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 12.44,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Date': '2020-02-23 20:25:23',
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 37.4,
#   'Humidity': 59,
#   'Cloudiness': 25,
#   'Wind Speed': 25.28,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Date': '2020-02-23 20:25:23',
#   'Lat': -5.2,
#   'Lng': -35.46,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 58,
#   'Wind Speed': 18.34,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tela',
#   'Country': 'HN',
#   'Date': '2020-02-23 20:21:51',
#   'Lat': 15.78,
#   'Lng': -87.45,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Campobello Di Mazara',
#   'Country': 'IT',
#   'Date': '2020-02-23 20:25:24',
#   'Lat': 37.64,
#   'Lng': 12.74,
#   'Max Temp': 62.01,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tarko-Sale',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:25:24',
#   'Lat': 64.92,
#   'Lng': 77.78,
#   'Max Temp': 19,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 21.77,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Nioro',
#   'Country': 'GM',
#   'Date': '2020-02-23 20:25:24',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 86.31,
#   'Humidity': 31,
#   'Cloudiness': 96,
#   'Wind Speed': 8.48,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Shelburne',
#   'Country': 'CA',
#   'Date': '2020-02-23 20:24:49',
#   'Lat': 44.08,
#   'Lng': -80.2,
#   'Max Temp': 48.2,
#   'Humidity': 45,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Date': '2020-02-23 20:25:25',
#   'Lat': 27.98,
#   'Lng': -114.06,
#   'Max Temp': 64.15,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 18.7,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Olinda',
#   'Country': 'BR',
#   'Date': '2020-02-23 20:25:25',
#   'Lat': -8.01,
#   'Lng': -34.86,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Uyskoye',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:25:25',
#   'Lat': 54.38,
#   'Lng': 60,
#   'Max Temp': 7.63,
#   'Humidity': 96,
#   'Cloudiness': 5,
#   'Wind Speed': 8.61,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Nyurba',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:25:25',
#   'Lat': 63.28,
#   'Lng': 118.33,
#   'Max Temp': -6.61,
#   'Humidity': 96,
#   'Cloudiness': 91,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Fort Nelson',
#   'Country': 'CA',
#   'Date': '2020-02-23 20:23:53',
#   'Lat': 58.81,
#   'Lng': -122.7,
#   'Max Temp': 23,
#   'Humidity': 53,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Praia Da Vitoria',
#   'Country': 'PT',
#   'Date': '2020-02-23 20:25:26',
#   'Lat': 38.73,
#   'Lng': -27.07,
#   'Max Temp': 59,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 7.14,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tilichiki',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:25:26',
#   'Lat': 60.47,
#   'Lng': 166.1,
#   'Max Temp': -5.6,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Date': '2020-02-23 20:25:18',
#   'Lat': -15.2,
#   'Lng': 12.15,
#   'Max Temp': 74.35,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 7.16,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Bandar',
#   'Country': 'ID',
#   'Date': '2020-02-23 20:25:26',
#   'Lat': 2.05,
#   'Lng': 99.75,
#   'Max Temp': 72.86,
#   'Humidity': 92,
#   'Cloudiness': 38,
#   'Wind Speed': 0.45,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Charters Towers',
#   'Country': 'AU',
#   'Date': '2020-02-23 20:25:27',
#   'Lat': -20.1,
#   'Lng': 146.27,
#   'Max Temp': 74.14,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 10.83,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Limbe',
#   'Country': 'CM',
#   'Date': '2020-02-23 20:25:27',
#   'Lat': 4.02,
#   'Lng': 9.21,
#   'Max Temp': 86,
#   'Humidity': 84,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Marsh Harbour',
#   'Country': 'BS',
#   'Date': '2020-02-23 20:25:27',
#   'Lat': 26.54,
#   'Lng': -77.06,
#   'Max Temp': 68.11,
#   'Humidity': 60,
#   'Cloudiness': 22,
#   'Wind Speed': 15.41,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Skibbereen',
#   'Country': 'IE',
#   'Date': '2020-02-23 20:25:27',
#   'Lat': 51.55,
#   'Lng': -9.27,
#   'Max Temp': 41,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'light intensity drizzle rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Bagotville',
#   'Country': 'AU',
#   'Date': '2020-02-23 20:25:27',
#   'Lat': -28.98,
#   'Lng': 153.42,
#   'Max Temp': 68,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 2.59,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'San Policarpo',
#   'Country': 'PH',
#   'Date': '2020-02-23 20:25:28',
#   'Lat': 12.18,
#   'Lng': 125.51,
#   'Max Temp': 78.6,
#   'Humidity': 86,
#   'Cloudiness': 6,
#   'Wind Speed': 15.23,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.69,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Mitsamiouli',
#   'Country': 'KM',
#   'Date': '2020-02-23 20:25:28',
#   'Lat': -11.38,
#   'Lng': 43.28,
#   'Max Temp': 84.56,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 10.16,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.19,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Waitati',
#   'Country': 'NZ',
#   'Date': '2020-02-23 20:25:28',
#   'Lat': -45.75,
#   'Lng': 170.57,
#   'Max Temp': 64,
#   'Humidity': 67,
#   'Cloudiness': 46,
#   'Wind Speed': 3,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tahoua',
#   'Country': 'NE',
#   'Date': '2020-02-23 20:25:28',
#   'Lat': 14.89,
#   'Lng': 5.27,
#   'Max Temp': 76.69,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 14.65,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Chimore',
#   'Country': 'BO',
#   'Date': '2020-02-23 20:25:28',
#   'Lat': -16.98,
#   'Lng': -65.13,
#   'Max Temp': 84.56,
#   'Humidity': 51,
#   'Cloudiness': 66,
#   'Wind Speed': 1.99,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Jackson',
#   'Country': 'US',
#   'Date': '2020-02-23 20:25:29',
#   'Lat': 42.42,
#   'Lng': -122.83,
#   'Max Temp': 60.01,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Kwinana',
#   'Country': 'AU',
#   'Date': '2020-02-23 20:25:29',
#   'Lat': -32.25,
#   'Lng': 115.77,
#   'Max Temp': 72,
#   'Humidity': 73,
#   'Cloudiness': 49,
#   'Wind Speed': 18.34,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.44,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'La Palma',
#   'Country': 'US',
#   'Date': '2020-02-23 20:25:29',
#   'Lat': 33.85,
#   'Lng': -118.05,
#   'Max Temp': 66.99,
#   'Humidity': 55,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Antalaha',
#   'Country': 'MG',
#   'Date': '2020-02-23 20:25:30',
#   'Lat': -14.9,
#   'Lng': 50.28,
#   'Max Temp': 79.32,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 10.8,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3hrs)': 3.63,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Port Augusta',
#   'Country': 'AU',
#   'Date': '2020-02-23 20:25:30',
#   'Lat': -32.5,
#   'Lng': 137.77,
#   'Max Temp': 71.01,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Kovdor',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:25:30',
#   'Lat': 67.57,
#   'Lng': 30.48,
#   'Max Temp': 18.93,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 5.57,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tatarsk',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:25:30',
#   'Lat': 55.22,
#   'Lng': 75.98,
#   'Max Temp': 10.31,
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 3.04,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Anadyr',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:25:30',
#   'Lat': 64.75,
#   'Lng': 177.48,
#   'Max Temp': -20,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sorong',
#   'Country': 'ID',
#   'Date': '2020-02-23 20:25:31',
#   'Lat': -0.88,
#   'Lng': 131.25,
#   'Max Temp': 74.95,
#   'Humidity': 98,
#   'Cloudiness': 98,
#   'Wind Speed': 2.08,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Port Blair',
#   'Country': 'IN',
#   'Date': '2020-02-23 20:25:31',
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 80.69,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 11.63,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Gotsu',
#   'Country': 'JP',
#   'Date': '2020-02-23 20:25:31',
#   'Lat': 35,
#   'Lng': 132.22,
#   'Max Temp': 49.95,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 17.11,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'College',
#   'Country': 'US',
#   'Date': '2020-02-23 20:25:31',
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': -2,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'General Roca',
#   'Country': 'AR',
#   'Date': '2020-02-23 20:25:32',
#   'Lat': -39.03,
#   'Lng': -67.58,
#   'Max Temp': 91.4,
#   'Humidity': 22,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Szydlowiec',
#   'Country': 'PL',
#   'Date': '2020-02-23 20:25:32',
#   'Lat': 51.23,
#   'Lng': 20.86,
#   'Max Temp': 46,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 19.66,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3hrs)': 8.81,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Trelew',
#   'Country': 'AR',
#   'Date': '2020-02-23 20:25:32',
#   'Lat': -43.25,
#   'Lng': -65.31,
#   'Max Temp': 66.16,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 21.03,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Misratah',
#   'Country': 'LY',
#   'Date': '2020-02-23 20:25:32',
#   'Lat': 32.38,
#   'Lng': 15.09,
#   'Max Temp': 58.64,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 13.11,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Fukumitsu',
#   'Country': 'JP',
#   'Date': '2020-02-23 20:25:32',
#   'Lat': 36.55,
#   'Lng': 136.87,
#   'Max Temp': 39.99,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Quatre Cocos',
#   'Country': 'MU',
#   'Date': '2020-02-23 20:25:33',
#   'Lat': -20.21,
#   'Lng': 57.76,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Oktyabrskiy',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:25:33',
#   'Lat': 54.48,
#   'Lng': 53.47,
#   'Max Temp': 23.36,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 17.27,
#   'Current Description': 'light snow',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.25},
#  {'City': 'Kedrovyy',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:25:33',
#   'Lat': 56.17,
#   'Lng': 91.82,
#   'Max Temp': 10.4,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 1.72,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Kamina',
#   'Country': 'CD',
#   'Date': '2020-02-23 20:25:33',
#   'Lat': -8.74,
#   'Lng': 24.99,
#   'Max Temp': 67.01,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 1.31,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Trairi',
#   'Country': 'BR',
#   'Date': '2020-02-23 20:25:33',
#   'Lat': -3.28,
#   'Lng': -39.27,
#   'Max Temp': 76.59,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 2.53,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Antsohihy',
#   'Country': 'MG',
#   'Date': '2020-02-23 20:25:34',
#   'Lat': -14.88,
#   'Lng': 47.99,
#   'Max Temp': 76.8,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Pelym',
#   'Country': 'RU',
#   'Date': '2020-02-23 20:25:34',
#   'Lat': 61.01,
#   'Lng': 62,
#   'Max Temp': 26.49,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 13.13,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0}]

# %%
len(city_data)
# Out:
# 575

# %%
# Create a city dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country                 Date    Lat     Lng  Max Temp  \
# 0      Qaqortoq      GL  2020-02-23 20:23:18  60.72  -46.03      24.8
# 1     Cape Town      ZA  2020-02-23 20:20:11 -33.93   18.42      68.0
# 2      Tasiilaq      GL  2020-02-23 20:20:12  65.61  -37.64      12.2
# 3   Yellowknife      CA  2020-02-23 20:20:12  62.46 -114.35      -4.0
# 4        Samana      DO  2020-02-23 20:20:12  19.21  -69.34      75.2
# 5   Port Alfred      ZA  2020-02-23 20:20:12 -33.59   26.89      61.0
# 6       Mataura      NZ  2020-02-23 20:20:13 -46.19  168.86      55.0
# 7       Ushtobe      KZ  2020-02-23 20:20:13  45.25   77.98      30.9
# 8         Vaini      TO  2020-02-23 20:20:13 -21.20 -175.20      80.6
# 9  Punta Arenas      CL  2020-02-23 20:20:13 -53.15  -70.92      55.4
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        53         100        9.17          light snow
# 1        56           0       20.80           clear sky
# 2        66          60       17.22       broken clouds
# 3        63          20        6.93          few clouds
# 4        94          75        4.70          light rain
# 5        81          50        2.01    scattered clouds
# 6        89          77        5.01       broken clouds
# 7        87          93        1.92     overcast clouds
# 8        88          40        9.17    scattered clouds
# 9        62          75       32.21       broken clouds
#
#    Rain inches (last 3hrs)  Snow inches (last 3hrs)
# 0                      0.0                     0.94
# 1                      0.0                     0.00
# 2                      0.0                     0.00
# 3                      0.0                     0.00
# 4                      0.0                     0.00
# 5                      0.0                     0.00
# 6                      0.0                     0.00
# 7                      0.0                     0.00
# 8                      0.0                     0.00
# 9                      0.0                     0.00

# %%
#Export the dataframe to csv file.
city_data_df.to_csv("data/WeatherPy_challenge.csv", index_label="City ID")

# %%
# Number of Cities recorded with snowfall and rainfall.
cities_rain_snow_count = len(city_data_df[(city_data_df["Rain inches (last 3hrs)"] > 0) | (city_data_df["Rain inches (last 3hrs)"] > 0)])

cities_rain_snow_count
# Out:
# 61
