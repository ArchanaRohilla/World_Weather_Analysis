# %%
#Import the dependencies.
import pandas as pd
import gmaps
import requests

#Import the API key.
from config import g_key

# %%
#Store the csv you saved created in part one into a dataframe.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID            City Country                 Date    Lat     Lng  \
# 0        0  Port Elizabeth      ZA  2020-02-21 19:52:22 -33.92   25.57
# 1        1            Chuy      UY  2020-02-21 19:52:23 -33.70  -53.46
# 2        2        Wencheng      CN  2020-02-21 19:52:23  33.06  113.80
# 3        3         Aklavik      CA  2020-02-21 19:52:23  68.22 -135.01
# 4        4           Kapaa      US  2020-02-21 19:52:24  22.08 -159.32
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     69.80        88          20        8.05
# 1     64.53        51          64       18.05
# 2     41.52        46           0        3.11
# 3      3.20        84          90       11.41
# 4     75.20        69          40        4.70

# %%
#Get the data types.
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
#Configure gmaps to use your google api key.
gmaps.configure(api_key=g_key)

# %%
# Get the max teperature.
max_temp =  city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature.
# Get the latitude and longitude.
locations=city_data_df[["Lat","Lng"]]


#Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

#Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp,0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)

#Add the heatmap layer.
fig.add_layer(heat_layer)

#Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness.
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of wind speed.
locations = city_data_df[["Lat", "Lng"]]
wind_speed = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind_speed, dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Ask for user input for minimum and maximum temperature.
print("What are your preffered temperatures?")
min_temp = float(input("min_temp: "))
max_temp = float(input("max_temp: "))

#List of recommended cities rec_cities.
rec_cities = city_data_df.loc[(city_data_df["Max Temp"] > min_temp) & (city_data_df["Max Temp"] < max_temp)]
# Out:
# What are your preffered temperatures?
# min_temp: 75
# max_temp: 90

# %%
rec_cities.head()
# Out:
#     City_ID        City Country                 Date    Lat     Lng  Max Temp  \
# 4         4       Kapaa      US  2020-02-21 19:52:24  22.08 -159.32     75.20
# 5         5  Port Blair      IN  2020-02-21 19:52:24  11.67   92.75     81.43
# 6         6     Rikitea      PF  2020-02-21 19:52:24 -23.12 -134.97     78.96
# 12       12   Hithadhoo      MV  2020-02-21 19:52:25  -0.60   73.08     82.69
# 13       13        Poum      NC  2020-02-21 19:52:25 -20.23  164.02     80.56
#
#     Humidity  Cloudiness  Wind Speed
# 4         69          40        4.70
# 5         76           0       16.15
# 6         61          49        6.20
# 12        78          94       13.76
# 13        79           1       15.82

# %%
rec_cities.count()
# Out:
# City_ID       180
# City          180
# Country       180
# Date          180
# Lat           180
# Lng           180
# Max Temp      180
# Humidity      180
# Cloudiness    180
# Wind Speed    180
# dtype: int64

# %%
rec_cities.isnull().sum()
# Out:
# City_ID       0
# City          0
# Country       0
# Date          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# dtype: int64

# %%
# Create DataFrame called lodging_df to store hotel names along with city, country, max temp, and coordinates.
lodging_df = rec_cities[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
lodging_df["Hotel Name"] = ""
lodging_df.head()
# Out:
#           City Country  Max Temp    Lat     Lng Hotel Name
# 4        Kapaa      US     75.20  22.08 -159.32
# 5   Port Blair      IN     81.43  11.67   92.75
# 6      Rikitea      PF     78.96 -23.12 -134.97
# 12   Hithadhoo      MV     82.69  -0.60   73.08
# 13        Poum      NC     80.56 -20.23  164.02

# %%
#Import the dependencies.
import pandas as pd
import gmaps
import requests

#Import the API key.
from config import g_key

# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key}

# %%
lodging_df.head()
# Out:
#           City Country  Max Temp    Lat     Lng Hotel Name
# 4        Kapaa      US     75.20  22.08 -159.32
# 5   Port Blair      IN     81.43  11.67   92.75
# 6      Rikitea      PF     78.96 -23.12 -134.97
# 12   Hithadhoo      MV     82.69  -0.60   73.08
# 13        Poum      NC     80.56 -20.23  164.02

# %%
# Adding the hotel names
for index,row in lodging_df.iterrows():
    #Get the latitude and longitude
    lat = row["Lat"]
    lng = row["Lng"]

    #Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    
    #Use the search term "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
       
    #Make request and get the json data from the search
    hotels = requests.get(base_url, params=params).json()
    
    print(params)
    #Grab the first hotel from the results and store the name.
    try:
        lodging_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except(IndexError):
        print("Hotel not found....skipping")
# Out:
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '22.08,-159.32'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '11.67,92.75'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-23.12,-134.97'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-0.6,73.08'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-20.23,164.02'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-24.79,-50.01'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-0.74,-90.35'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-21.21,-159.78'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '5.95,80.54'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-22.97,-42.03'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '10.84,121.01'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-33.65,115.33'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-3.9,-38.39'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '11.92,109.16'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-20.41,57.7'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '33.87,-118.08'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '5.41,100.34'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-19.06,-169.92'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '9.54,-13.68'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-17.71,-39.25'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-9.66,120.26'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-12.93,-49.83'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-2.54,-57.76'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-11.1,-77.61'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-3.28,-39.27'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-14.25,129.55'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '1.5,21.05'}
# Hotel not found....skipping
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-9.8,-139.03'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '20.5,-10.07'}
# Hotel not found....skipping
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-21.2,-175.2'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '10.57,72.64'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '5.97,80.42'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-24.87,113.63'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-2.57,150.8'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-33.02,27.91'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-16.1,167.42'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-21.36,55.77'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-20.34,57.76'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-9.44,147.18'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-10.21,-48.36'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-15.2,12.15'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-41.87,-73.82'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '6.12,81.12'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-16.48,-151.75'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '5.77,73.38'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-3.4,-78.55'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-37.62,-73.65'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '5.35,48.53'}
# Hotel not found....skipping
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '7.77,-72.22'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '2.77,-77.67'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '2.67,72.89'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '5.89,95.32'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-2.02,147.27'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '9.49,50.81'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '17.33,42.67'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '12.42,75.73'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-51.62,-69.22'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '19.22,-104.7'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '3.07,172.79'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '10.34,-68.74'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '4.87,-2.24'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '12.48,-16.55'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-7.91,39.67'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-12.07,134.27'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '21.28,-88.27'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '0.57,12.86'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-0.72,8.78'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '10.46,-64.18'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-19.31,-48.92'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-22.63,-54.82'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '-8.84,13.23'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI', 'location': '15.4,-89.83'}
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     484             try:
# --> 485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1933         result = _lib.SSL_do_handshake(self._ssl)
# -> 1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1663                         raise SysCallError(errno, errorcode.get(errno))
# -> 1664                 raise SysCallError(-1, "Unexpected EOF")
#    1665             else:
#
# SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connection.py in connect(self)
#     359             server_hostname=server_hostname,
# --> 360             ssl_context=context,
#     361         )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     369         if HAS_SNI and server_hostname is not None:
# --> 370             return context.wrap_socket(sock, server_hostname=server_hostname)
#     371
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     490             except OpenSSL.SSL.Error as e:
# --> 491                 raise ssl.SSLError("bad handshake: %r" % e)
#     492             break
#
# SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI&location=-20.52%2C57.52 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-17-735c212b41ce> in <module>
#      13
#      14     #Make request and get the json data from the search
# ---> 15     hotels = requests.get(base_url, params=params).json()
#      16
#      17     print(params)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyAT07NTbCq7aFjBIMIFVw0w2KSaXsTMoOI&location=-20.52%2C57.52 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))

# %%
len(hotels["results"])
# Out:
# 6

# %%
lodging_df.head(30)
# Out:
#                City Country  Max Temp    Lat     Lng  \
# 4             Kapaa      US     75.20  22.08 -159.32
# 5        Port Blair      IN     81.43  11.67   92.75
# 6           Rikitea      PF     78.96 -23.12 -134.97
# 12        Hithadhoo      MV     82.69  -0.60   73.08
# 13             Poum      NC     80.56 -20.23  164.02
# 18           Castro      BR     76.80 -24.79  -50.01
# 19     Puerto Ayora      EC     80.60  -0.74  -90.35
# 21           Avarua      CK     82.40 -21.21 -159.78
# 22           Matara      LK     79.23   5.95   80.54
# 28  Arraial Do Cabo      BR     82.40 -22.97  -42.03
# 30             Suba      PH     78.55  10.84  121.01
# 31        Busselton      AU     77.00 -33.65  115.33
# 32          Aquiraz      BR     86.00  -3.90  -38.39
# 34         Cam Ranh      VN     77.00  11.92  109.16
# 37        Mahebourg      MU     78.01 -20.41   57.70
# 41          Artesia      US     79.00  33.87 -118.08
# 42       Georgetown      MY     80.60   5.41  100.34
# 43            Alofi      NU     78.80 -19.06 -169.92
# 49          Conakry      GN     79.43   9.54  -13.68
# 55        Caravelas      BR     81.70 -17.71  -39.25
# 58         Waingapu      ID     82.85  -9.66  120.26
# 59         Araguacu      BR     79.41 -12.93  -49.83
# 61          Urucara      BR     81.84  -2.54  -57.76
# 66          Hualmay      PE     78.22 -11.10  -77.61
# 68           Trairi      BR     76.48  -3.28  -39.27
# 77       Port Keats      AU     85.95 -14.25  129.55
# 83      Bongandanga      CD     77.23   1.50   21.05
# 85           Atuona      PF     81.77  -9.80 -139.03
# 89            Adrar      MR     77.77  20.50  -10.07
# 91            Vaini      TO     77.00 -21.20 -175.20
#
#                                       Hotel Name
# 4         Sheraton Kauai Resort at Coconut Beach
# 5                      Fortune Resort Bay Island
# 6                                 Pension Maro'i
# 12                             Scoop Guest House
# 13                                   Gîte kajeon
# 18                                CHACARA BAILLY
# 19                     Finch Bay Galapagos Hotel
# 21                                  Paradise Inn
# 22                        Amaloh Boutique Resort
# 28                           Pousada Porto Praia
# 30                           Suba Pensione House
# 31                       Observatory Guest House
# 32                              Hotel Laguna Blu
# 34                           OYO 598 Peony Hotel
# 37            Shandrani Beachcomber Resort & Spa
# 41  La Quinta Inn & Suites by Wyndham Buena Park
# 42                                Cititel Penang
# 43                                 Taloa Heights
# 49                           Riviera Royal Hotel
# 55                        Pousada dos Navegantes
# 58                            Pondok Wisata Elim
# 59                             Brunas Park Hotel
# 61                    Hotel Pousada Maria Bonita
# 66         Hotel Restaurant Turístico Casablanca
# 68                 Pousada Field Lilies - Trairi
# 77                TDC Village (Hundred Man Camp)
# 83
# 85                                   Villa Enata
# 89
# 91                           Keleti Beach Resort

# %%
#Create the heatmap of temperature for the vacation spots and marker for each city.
locations = rec_cities[["Lat","Lng"]]
max_temp = rec_cities["Max Temp"]
fig=gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer=gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

#Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in lodging_df.iterrows()]

# %%
#Create the heatmap of temperature for the vacation spots and marker for each city.
locations = lodging_df[["Lat","Lng"]]
max_temp = lodging_df["Max Temp"]
fig=gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer=gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

#Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
